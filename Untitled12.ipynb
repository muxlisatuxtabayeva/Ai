# %% [markdown]
# <a href="https://colab.research.google.com/github/muxlisatuxtabayeva/Ai/blob/test/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('19.CSV')
print(df)
# Out:
#           Series_reference   Period  Data_value       STATUS  \
# 0         GFSA.SLS01G01Z90  2009.06         715        FINAL
# 1         GFSA.SLS01G01Z90  2010.06         907        FINAL
# 2         GFSA.SLS01G01Z90  2011.06         350        FINAL
# 3         GFSA.SLS01G01Z90  2012.06         512        FINAL
# 4         GFSA.SLS01G01Z90  2013.06        1033        FINAL
# ...                    ...      ...         ...          ...
# 2825  GFSA.SLS05G08Z61613Z  2021.06           0        FINAL
# 2826  GFSA.SLS05G08Z61613Z  2022.06           0        FINAL
# 2827  GFSA.SLS05G08Z61613Z  2023.06           0        FINAL
# 2828  GFSA.SLS05G08Z61613Z  2024.06           0        FINAL
# 2829  GFSA.SLS05G08Z61613Z  2025.06           0  PROVISIONAL
#
#                                                   Group  \
# 0     Local Government, Operating Statement, Net Bal...
# 1     Local Government, Operating Statement, Net Bal...
# 2     Local Government, Operating Statement, Net Bal...
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  2830 non-null   object
#  1   Period            2830 non-null   float64
#  2   Data_value        2830 non-null   int64
#  3   STATUS            2830 non-null   object
#  4   Group             2830 non-null   object
#  5   Subject           2830 non-null   object
#  6   Series_title_1    2830 non-null   object
#  7   Series_title_2    1640 non-null   object
#  8   Series_title_3    790 non-null    object
#  9   Series_title_4    516 non-null    object
#  10  Series_title_5    0 non-null      float64
#  11  UNITS             2830 non-null   object
#  12  MAGNTUDE          2830 non-null   int64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 287.6+ KB
# None
