# %% [markdown]
# <a href="https://colab.research.google.com/github/muxlisatuxtabayeva/Ai/blob/main/untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame as df
df=pd.read_csv('19.CSV')
print(df)
# Out:
#           Series_reference   Period  ...    UNITS MAGNTUDE
# 0         GFSA.SLS01G01Z90  2009.06  ...  Dollars        6
# 1         GFSA.SLS01G01Z90  2010.06  ...  Dollars        6
# 2         GFSA.SLS01G01Z90  2011.06  ...  Dollars        6
# 3         GFSA.SLS01G01Z90  2012.06  ...  Dollars        6
# 4         GFSA.SLS01G01Z90  2013.06  ...  Dollars        6
# ...                    ...      ...  ...      ...      ...
# 2825  GFSA.SLS05G08Z61613Z  2021.06  ...  Dollars        6
# 2826  GFSA.SLS05G08Z61613Z  2022.06  ...  Dollars        6
# 2827  GFSA.SLS05G08Z61613Z  2023.06  ...  Dollars        6
# 2828  GFSA.SLS05G08Z61613Z  2024.06  ...  Dollars        6
# 2829  GFSA.SLS05G08Z61613Z  2025.06  ...  Dollars        6
#
# [2830 rows x 13 columns]

# %%
print(df.columns)
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'STATUS', 'Group',
#        'Subject', 'Series_title_1', 'Series_title_2', 'Series_title_3',
#        'Series_title_4', 'Series_title_5', 'UNITS', 'MAGNTUDE'],
#       dtype='object')

# %%
obj=Series(df.index)
print(obj)
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 2825    2825
# 2826    2826
# 2827    2827
# 2828    2828
# 2829    2829
# Length: 2830, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_226/1892086286.py in <cell line: 0>()
# ----> 1 obj[ obj>1000 and obj<2000]
#       2
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
